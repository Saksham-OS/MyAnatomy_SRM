# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('zomato_eda_mini_project.csv')

# %%
df.head()
# Out:
#   Restaurant Name     City              Cuisines  Average Cost for two  \
# 0     Ocean Pearl   Mumbai  Seafood, Continental                1450.0
# 1   Pizza Central     Pune        Pizza, Italian                 300.0
# 2      Cafe Aroma     Pune        Cafe, Desserts                 250.0
# 3      Cafe Aroma     Pune        Cafe, Desserts                1850.0
# 4  Bengal Kitchen  Kolkata                   NaN                 150.0
#
#    Price range  Aggregate rating  Votes
# 0            3               3.7  827.0
# 1            1               3.8  415.0
# 2            1               2.7  112.0
# 3            4               4.4  741.0
# 4            1               3.8  635.0

# %%
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(data = df, x = 'Aggregate rating', bins = 5, kde = True)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Count'>

# %%
sns.distplot(data = df, x = 'Aggregate rating', bins = 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.distplot(data = df, x = 'Aggregate rating', bins = 10)
#
# TypeError: distplot() got an unexpected keyword argument 'data'

# %%
sns.boxplot(data = df ,x = 'City', y = 'Aggregate rating')
# Out:
# <Axes: xlabel='City', ylabel='Aggregate rating'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(data = df ,x = 'City', y = 'Average Cost for two')
# Out:
# <Axes: xlabel='City', ylabel='Average Cost for two'>

# %%
sns.barplot(data = df, x = 'City', y = 'Average Cost for two')
# Out:
# <Axes: xlabel='City', ylabel='Average Cost for two'>

# %%
sns.distplot(df['Aggregate rating'])
# Out:
# C:\Users\saksh_qhj138e\AppData\Local\Temp\ipykernel_4860\95774152.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Aggregate rating'])
# <Axes: xlabel='Aggregate rating', ylabel='Density'>

# %%
sns.violinplot(df['Average Cost for two'])
# Out:
# <Axes: ylabel='Average Cost for two'>

# %% [markdown]
# DISCRIPTIVE STATS : What does my data show.
# INFERENTIAL STATS : What can I conclude about a large population.
